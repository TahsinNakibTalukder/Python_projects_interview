# %%
import pandas as pd

# %%
df = pd.read_csv("cars.csv")

# %%
print(df.head())
# Out:
#                                                 info
# 0  Car;MPG;Cylinders;Displacement;Horsepower;Weig...
# 1  STRING;DOUBLE;INT;DOUBLE;DOUBLE;DOUBLE;DOUBLE;...
# 2  Chevrolet Chevelle Malibu;18.0;8;307.0;130.0;3...
# 3  Buick Skylark 320;15.0;8;350.0;165.0;3693.;11....
# 4  Plymouth Satellite;18.0;8;318.0;150.0;3436.;11...

# %%
print(df.columns)
# Out:
# Index(['info'], dtype='object')

# %%
df['info'].str.split(';')
# Out:
# 0      [Car, MPG, Cylinders, Displacement, Horsepower...
# 1      [STRING, DOUBLE, INT, DOUBLE, DOUBLE, DOUBLE, ...
# 2      [Chevrolet Chevelle Malibu, 18.0, 8, 307.0, 13...
# 3      [Buick Skylark 320, 15.0, 8, 350.0, 165.0, 369...
# 4      [Plymouth Satellite, 18.0, 8, 318.0, 150.0, 34...
#                              ...
# 403    [Ford Mustang GL, 27.0, 4, 140.0, 86.00, 2790....
# 404    [Volkswagen Pickup, 44.0, 4, 97.00, 52.00, 213...
# 405    [Dodge Rampage, 32.0, 4, 135.0, 84.00, 2295., ...
# 406    [Ford Ranger, 28.0, 4, 120.0, 79.00, 2625., 18...
# 407    [Chevy S-10, 31.0, 4, 119.0, 82.00, 2720., 19....
# Name: info, Length: 408, dtype: object

# %%
split_info = df['info'].str.split(';', expand = True)

# %% [markdown]
# #### adding new columns

# %%
df = split_info.rename(columns={0:'Car', 1:'MPG', 2:'Cylinders', 3:'Displacement', 4:'Horsepower', 5:'Weight', 6:'Acceleration', 7:'Model', 8:'Origin'})

# %%
df
# Out:
#                            Car     MPG  Cylinders  Displacement  Horsepower  \
# 0                          Car     MPG  Cylinders  Displacement  Horsepower
# 1                       STRING  DOUBLE        INT        DOUBLE      DOUBLE
# 2    Chevrolet Chevelle Malibu    18.0          8         307.0       130.0
# 3            Buick Skylark 320    15.0          8         350.0       165.0
# 4           Plymouth Satellite    18.0          8         318.0       150.0
# ..                         ...     ...        ...           ...         ...
# 403            Ford Mustang GL    27.0          4         140.0       86.00
# 404          Volkswagen Pickup    44.0          4         97.00       52.00
# 405              Dodge Rampage    32.0          4         135.0       84.00
# 406                Ford Ranger    28.0          4         120.0       79.00
# 407                 Chevy S-10    31.0          4         119.0       82.00
#
#      Weight  Acceleration  Model  Origin
# ...

# %%
df.shape
# Out:
# (408, 9)

# %%
df.set_index('Car')
# Out:
#                               MPG  Cylinders  Displacement  Horsepower  \
# Car
# Car                           MPG  Cylinders  Displacement  Horsepower
# STRING                     DOUBLE        INT        DOUBLE      DOUBLE
# Chevrolet Chevelle Malibu    18.0          8         307.0       130.0
# Buick Skylark 320            15.0          8         350.0       165.0
# Plymouth Satellite           18.0          8         318.0       150.0
# ...                           ...        ...           ...         ...
# Ford Mustang GL              27.0          4         140.0       86.00
# Volkswagen Pickup            44.0          4         97.00       52.00
# Dodge Rampage                32.0          4         135.0       84.00
# Ford Ranger                  28.0          4         120.0       79.00
# Chevy S-10                   31.0          4         119.0       82.00
#
#                            Weight  Acceleration  Model  Origin
# Car
# ...

# %%
df.iloc[2]
# Out:
# Car             Chevrolet Chevelle Malibu
# MPG                                  18.0
# Cylinders                               8
# Displacement                        307.0
# Horsepower                          130.0
# Weight                              3504.
# Acceleration                         12.0
# Model                                  70
# Origin                                 US
# Name: 2, dtype: object

# %%
df.drop([0,1], axis=0,inplace=True)

# %%
DataFrame= df.set_index('Car')

# %%
DataFrame
# Out:
#                             MPG Cylinders Displacement Horsepower Weight  \
# Car
# Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# Buick Skylark 320          15.0         8        350.0      165.0  3693.
# Plymouth Satellite         18.0         8        318.0      150.0  3436.
# AMC Rebel SST              16.0         8        304.0      150.0  3433.
# Ford Torino                17.0         8        302.0      140.0  3449.
# ...                         ...       ...          ...        ...    ...
# Ford Mustang GL            27.0         4        140.0      86.00  2790.
# Volkswagen Pickup          44.0         4        97.00      52.00  2130.
# Dodge Rampage              32.0         4        135.0      84.00  2295.
# Ford Ranger                28.0         4        120.0      79.00  2625.
# Chevy S-10                 31.0         4        119.0      82.00  2720.
#
#                           Acceleration Model  Origin
# Car
# ...

# %%
DataFrame.iloc[2]
# Out:
# MPG              18.0
# Cylinders           8
# Displacement    318.0
# Horsepower      150.0
# Weight          3436.
# Acceleration     11.0
# Model              70
# Origin             US
# Name: Plymouth Satellite, dtype: object

# %%
len(DataFrame)
# Out:
# 406
